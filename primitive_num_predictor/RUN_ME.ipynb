# %% [markdown]
# Чтобы понять, что здесь происходит - прочитай readme.md

# %% [markdown]
# # Импорты

# %%
from predictors import *
from plotter import dict_plotter

# %% [markdown]
# # Рэнкинг

# %%
# Создаем список для ранжирования
list_for_rank = [predictor_01_random_search, predictor_02_more_less, predictor_03_binary_search]

# Вычисляем результаты с помощью функции scorer и сохраняем их в список results
results = map(lambda x: scorer(x), list_for_rank)

# Преобразуем список results в словарь results_dict
results_dict = dict(results)

# Отображаем результаты
display(results_dict)
# Out:
# {'predictor_01_random_search': 99,
#  'predictor_02_more_less': 34,
#  'predictor_03_binary_search': 6}

# %% [markdown]
# # Визуализация

# %%
dict_plotter(results_dict)

# %%
# !pip freeze > requirements.txt

# %%
# !conda env export > environment.yml
